# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nplabels = np.load("dataset/label/labels_w_ud.npy")

# %%
height = []
label_num, count = np.unique(nplabels, return_counts=True)
for i, name in enumerate(["without", "Ak", "Al", "Mk", "Ml", "Gk", "Gl", "unclear"]):
    print(name, ": ", count[i])
    height.append(count[i])
# Out:
# without :  1007
# Ak :  48
# Al :  31
# Mk :  71
# Ml :  25
# Gk :  210
# Gl :  94
# unclear :  292

# %%
plt.bar(["without", "Ak", "Al", "Mk", "Ml", "Gk", "Gl", "unclear"], height)
# Out:
# <BarContainer object of 8 artists>
